# %%
# AAPL Time Series Chart
import pandas as pd
stock_data = pd.read_csv("C:/Users/capta/Desktop/6312-group project/AAPL202102.csv",index_col='Date')
stock_data=stock_data.sort_values(by='Date')
print(stock_data)

import matplotlib.pyplot as plt
stock_data['Volume(M)'].plot(grid=True,color='red',label='AAPL')
plt.title('2020-2021 volume(M)',fontsize='9')
plt.ylabel('Volume(M)',fontsize='8')
plt.xlabel('Date',fontsize='8')
plt.legend(loc='best',fontsize='small')
plt.show()
# Out:
#              Close    Open    High     Low  Volume(M) Fluctuation
# Date
# 2020-01-02   75.09   74.06   75.15   73.80     135.65       2.28%
# 2020-01-03   74.36   74.29   75.14   74.13     146.54      -0.97%
# 2020-01-06   74.95   73.45   74.99   73.19     118.58       0.80%
# 2020-01-07   74.60   74.96   75.22   74.37     111.51      -0.47%
# 2020-01-08   75.80   74.29   76.11   74.29     132.36       1.61%
# ...            ...     ...     ...     ...        ...         ...
# 2021-02-22  126.00  128.01  129.72  125.60     103.92      -2.98%
# 2021-02-23  125.86  123.76  126.71  118.39     158.27      -0.11%
# 2021-02-24  125.35  124.94  125.56  122.23     111.04      -0.41%
# 2021-02-25  120.99  124.68  126.46  120.54     148.20      -3.48%
# 2021-02-26  121.26  122.59  124.85  121.20     164.56       0.22%
#
# [291 rows x 6 columns]

# %%
# AMZN Time Series Chart
import pandas as pd
stock_data = pd.read_csv("C:/Users/capta/Desktop/6312-group project/AMZN202102.csv",index_col='Date')
stock_data=stock_data.sort_values(by='Date')
print(stock_data)

import matplotlib.pyplot as plt
stock_data['Volume(M)'].plot(grid=True,color='red',label='AMZN')
plt.title('2020-2021 volume(M)',fontsize='9')
plt.ylabel('Volume(M)',fontsize='8')
plt.xlabel('Date',fontsize='8')
plt.legend(loc='best',fontsize='small')
plt.show()
# Out:
#                Close      Open      High       Low  Volume(M) Fluctuation
# Date
# 2020-01-02  1,898.01  1,875.00  1,898.01  1,864.15       4.04       2.72%
# 2020-01-03  1,874.97  1,864.50  1,886.20  1,864.50       3.77      -1.21%
# 2020-01-06  1,902.88  1,860.00  1,903.69  1,860.00       4.07       1.49%
# 2020-01-07  1,906.86  1,904.50  1,913.89  1,892.04       4.13       0.21%
# 2020-01-08  1,891.97  1,898.04  1,911.00  1,886.44       3.51      -0.78%
# ...              ...       ...       ...       ...        ...         ...
# 2021-02-22  3,180.74  3,210.00  3,230.00  3,173.04       3.52      -2.13%
# 2021-02-23  3,194.50  3,127.79  3,204.18  3,095.00       4.68       0.43%
# 2021-02-24  3,159.53  3,166.75  3,171.23  3,125.38       3.01      -1.09%
# 2021-02-25  3,057.16  3,135.09  3,174.96  3,048.59       4.53      -3.24%
# 2021-02-26  3,092.93  3,095.20  3,122.44  3,036.70       4.28       1.17%
#
# [291 rows x 6 columns]

# %%
# AAPL K-line Chart
import numpy as np
import pandas as pd
import mpl_finance as mpf
import matplotlib.pyplot as plt
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, WeekdayLocator, DayLocator, MONDAY, date2num

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
df_ma = pd.DataFrame()
stock_data = pd.read_csv("C:/Users/capta/Desktop/6312-group project/AAPL202102.csv")

opens = stock_data['Open'][0:days]
closes = stock_data['Close'][0:days]
highs = stock_data['High'][0:days]
lows = stock_data['Low'][0:days]

data_index = stock_data['Date'][0:days]
ohlc = list(zip(np.arange(0,len(opens)),opens,closes,highs,lows))
mpf.candlestick2_ochl(ax,opens,closes,highs,lows,width=0.6,colorup='red',colordown='green')
ax.set_xlim(0,days)
ax.set_xticks(np.arange(0,days,30))
ax.set_xticklabels([data_index[index] for index in ax.get_xticks()])
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Price',fontsize=15)
ax.set_title('AAPL')
plt.show()

# %%
# AMZN K-line Chart
import numpy as np
import pandas as pd
import mpl_finance as mpf
import matplotlib.pyplot as plt
from mpl_finance import candlestick_ohlc
from matplotlib.dates import DateFormatter, WeekdayLocator, DayLocator, MONDAY, date2num

fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
df_ma = pd.DataFrame()
stock_data = pd.read_csv("C:/Users/capta/Desktop/6312-group project/AMZN202102.csv")

opens = stock_data['Open'][0:days]
closes = stock_data['Close'][0:days]
highs = stock_data['High'][0:days]
lows = stock_data['Low'][0:days]

data_index = stock_data['Date'][0:days]
ohlc = list(zip(np.arange(0,len(opens)),opens,closes,highs,lows))
mpf.candlestick2_ochl(ax,opens,closes,highs,lows,width=0.6,colorup='red',colordown='green')
ax.set_xlim(0,days)
ax.set_xticks(np.arange(0,days,30))
ax.set_xticklabels([data_index[index] for index in ax.get_xticks()])
ax.set_xlabel('Date',fontsize=15)
ax.set_ylabel('Price',fontsize=15)
ax.set_title('AMZN')
plt.show()

# %%
#stock price prediction for AAPL_using LR
import numpy as np
import pandas as pd
from sklearn import preprocessing
import quandl
quandl.ApiConfig.api_key= "dR3ZnxHyEGd5ZcqTssev"
import math

df = quandl.get('WIKI/AAPL')
forecast_col = 'Adj. Close'
forecast_out = int(math.ceil(0.01*len(df)))
df = df[['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0
df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]
df.fillna(-99999, inplace=True)
df['label'] = df[forecast_col].shift(-forecast_out)
X = np.array(df.drop(['label'], 1))
X = preprocessing.scale(X)

X_lately = X[-forecast_out:]
X = X[:-forecast_out]

df.dropna(inplace=True)
y = np.array(df['label'])

from sklearn import  model_selection, svm
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)
clf = LinearRegression(n_jobs=-1)

clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)

forecast_set = clf.predict(X_lately)
print(forecast_set, accuracy)
import matplotlib.pyplot as plt
from matplotlib import style
import datetime

style.use('ggplot')
one_day = 86400

df['Forecast'] = np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
next_unix = last_unix + one_day


for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    df.loc[next_date] = [np.nan for _ in range(len(df.columns) - 1)] + [i]

df['Adj. Close'].plot()
df['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\capta\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:174: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# [188.23669682 186.95750926 186.16850679 183.28382306 180.95056842
#  183.11439107 182.08824783 181.95991369 185.14776813 187.21979687
#  187.27570483 186.33212354 185.148119   181.21682111 183.88655971
#  183.007302   181.61283717 181.34682953 180.70846553 181.28825602
#  181.21538409 184.6188198  183.78988447 184.30010647 184.29409506
#  186.12239596 188.6784572  186.80329417 186.56876825 187.18510983
#  187.30403628 182.5457559  182.62524328 183.07751179 181.11952948
#  184.30300964 184.11239688 185.18028571 187.21686497 186.50355347
#  186.57454862 186.54193369 187.59708214 189.50787299 188.31298564
#  191.53120688 191.8155069  190.92570091 189.42371515 189.23698282
#  186.32775153 182.91500818 183.62936403 179.71631574 178.66355181
#  179.12016638 179.51933891 171.22221165 167.83858922 173.88893645
#  170.56893327 165.87111782 166.89005293 173.79055644 175.77622004
#  178.90461646 185.00741091 184.29564253 183.68890571 182.8730019
#  184.57167456 187.83112539 191.38003391 190.75689822 190.4378885
#  186.9505103  188.42477924 189.08040234 189.02108439 187.29251543
#  189.32116913 192.55277487 194.36025729 192.36567927 190.88520856
#  191.03734508 190.49508096 187.53300743 187.40996075 183.11203058
#  180.3395708  176.15476525 184.62028455 179.64661172] 0.9753708235297707

# %%
#stock price prediction for AMZN_using LR
import numpy as np
import pandas as pd
from sklearn import preprocessing
import quandl
quandl.ApiConfig.api_key= "dR3ZnxHyEGd5ZcqTssev"
import math

df = quandl.get('WIKI/AMZN')
forecast_col = 'Adj. Close'
forecast_out = int(math.ceil(0.01*len(df)))
df = df[['Adj. Open', 'Adj. High', 'Adj. Low', 'Adj. Close', 'Adj. Volume']]
df['HL_PCT'] = (df['Adj. High'] - df['Adj. Close']) / df['Adj. Close'] * 100.0
df['PCT_change'] = (df['Adj. Close'] - df['Adj. Open']) / df['Adj. Open'] * 100.0
df = df[['Adj. Close', 'HL_PCT', 'PCT_change', 'Adj. Volume']]
df.fillna(-99999, inplace=True)
df['label'] = df[forecast_col].shift(-forecast_out)
X = np.array(df.drop(['label'], 1))
X = preprocessing.scale(X)

X_lately = X[-forecast_out:]
X = X[:-forecast_out]

df.dropna(inplace=True)
y = np.array(df['label'])

from sklearn import  model_selection, svm
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2)
clf = LinearRegression(n_jobs=-1)

clf.fit(X_train, y_train)
accuracy = clf.score(X_test, y_test)

forecast_set = clf.predict(X_lately)
print(forecast_set, accuracy)
import matplotlib.pyplot as plt
from matplotlib import style
import datetime

style.use('ggplot')
one_day = 86400

df['Forecast'] = np.nan
last_date = df.iloc[-1].name
last_unix = last_date.timestamp()
next_unix = last_unix + one_day


for i in forecast_set:
    next_date = datetime.datetime.fromtimestamp(next_unix)
    next_unix += one_day
    df.loc[next_date] = [np.nan for _ in range(len(df.columns) - 1)] + [i]

df['Adj. Close'].plot()
df['Forecast'].plot()
plt.legend(loc=4)
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()
# Out:
# [1379.14188289 1403.89441403 1435.79922004 1436.58070547 1424.99162307
#  1422.71248152 1424.37428789 1459.96537477 1499.14207065 1494.55196625
#  1516.07508809 1542.69371283 1560.41380428 1582.39245756 1598.19653011
#  1531.47835667 1577.22714444 1539.08550681 1588.76286135 1560.35522123
#  1488.22492242 1475.71503434 1525.72095135 1556.74923076 1597.00714053
#  1608.99749777 1594.53905093 1616.62250335 1632.72962624 1634.4528049
#  1650.85525539 1675.21259811 1664.4611895  1664.94580091 1644.5875765
#  1651.51254886 1677.0922434  1692.56147879 1700.53192272 1708.05578761
#  1738.0061218  1759.81222709 1749.22084392 1751.64228636 1742.02579452
#  1730.53283092 1701.19090104 1746.41248534 1741.50860954 1700.49135444
#  1647.66930382 1712.77217192 1649.64543796] 0.9774793326208975
